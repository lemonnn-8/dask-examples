# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_squared_log_error
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import Pipeline
import dask.dataframe as dd
import pandas as pd
import numpy as np
import time
import re
from sklearn.externals import joblib
seed = 101

# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster(n_workers=10, threads_per_worker=20, dashboard_address=':0')
client = Client(cluster)
client
# Out:
# <Client: scheduler='tcp://127.0.0.1:37353' processes=10 cores=200>

# %%
def tokenizer(text):
    if text:
        result = re.findall('[a-z]{2,}', text.lower())
    else:
        result = []
    return result

# %%
df = dd.read_csv('train.tsv', sep='\t')
df = df.compute()

# %%
df['item_description'].fillna(value='Missing', inplace=True)
X = (df['name'] + ' ' + df['item_description']).values
y = np.log1p(df['price'].values)
with joblib.parallel_backend('dask'):
        X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3, random_state=seed)

# %%
with joblib.parallel_backend('dask'):
    vect = TfidfVectorizer(tokenizer=tokenizer, stop_words='english')
    start = time.time()
    X_train_vect = vect.fit_transform(X_train)
    end = time.time()
    print('Time to train vectorizer and transform training text: %0.2fs' % (end - start))
# Out:
# Time to train vectorizer and transform training text: 0.03s

# %%
#from dask_ml.model_selection import GridSearchCV
model = SGDRegressor(loss='squared_loss', penalty='none', random_state=seed, max_iter=500000, tol=1e-6)
params = {'penalty':['none','l2','l1'],
          'alpha':[1e-4, 2e-4, 5e-4, 1e-3, 2e-3, 5e-3, 1e-2, 2e-2, 5e-2, 0.1]}
gs = GridSearchCV(estimator=model,
                  param_grid=params,
                  scoring='neg_mean_squared_error',
                  cv=5,
                  n_jobs=-1, verbose = 3)
start = time.time()
gs.fit(X_train_vect, y_train)
end = time.time()
print('Time to train model: %0.2fs' % (end -start))
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] alpha=0.0001, penalty=none ......................................
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  alpha=0.0001, penalty=none, score=-0.7243991267042661, total=   2.1s
# [CV] alpha=0.0001, penalty=none ......................................
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [CV]  alpha=0.0001, penalty=none, score=-0.6597777867822803, total=   1.9s
# [CV] alpha=0.0001, penalty=none ......................................
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.0s remaining:    0.0s
# [CV]  alpha=0.0001, penalty=none, score=-0.5866548677506939, total=   2.0s
# [CV] alpha=0.0001, penalty=none ......................................
# [CV]  alpha=0.0001, penalty=none, score=-0.8116720767814963, total=   1.8s
# [CV] alpha=0.0001, penalty=none ......................................
# [CV]  alpha=0.0001, penalty=none, score=-0.8500709602066103, total=   1.8s
# [CV] alpha=0.0001, penalty=l2 ........................................
# [CV]  alpha=0.0001, penalty=l2, score=-0.685417377424021, total=   2.1s
# [CV] alpha=0.0001, penalty=l2 ........................................
# [CV]  alpha=0.0001, penalty=l2, score=-0.6235156975796732, total=   2.0s
# [CV] alpha=0.0001, penalty=l2 ........................................
# [CV]  alpha=0.0001, penalty=l2, score=-0.560044766818491, total=   2.0s
# [CV] alpha=0.0001, penalty=l2 ........................................
# [CV]  alpha=0.0001, penalty=l2, score=-0.7723449458165883, total=   2.0s
# [CV] alpha=0.0001, penalty=l2 ........................................
# [CV]  alpha=0.0001, penalty=l2, score=-0.8097006561402581, total=   1.9s
# [CV] alpha=0.0001, penalty=l1 ........................................
# [CV]  alpha=0.0001, penalty=l1, score=-0.6492522801048883, total=   3.2s
# [CV] alpha=0.0001, penalty=l1 ........................................
# [CV]  alpha=0.0001, penalty=l1, score=-0.597642929871327, total=   3.2s
# [CV] alpha=0.0001, penalty=l1 ........................................
# [CV]  alpha=0.0001, penalty=l1, score=-0.5358212212600827, total=   3.1s
# [CV] alpha=0.0001, penalty=l1 ........................................
# [CV]  alpha=0.0001, penalty=l1, score=-0.7547372990110428, total=   3.0s
# [CV] alpha=0.0001, penalty=l1 ........................................
# [CV]  alpha=0.0001, penalty=l1, score=-0.7836522533349759, total=   3.2s
# [CV] alpha=0.0002, penalty=none ......................................
# [CV]  alpha=0.0002, penalty=none, score=-0.7243991267042661, total=   2.1s
# [CV] alpha=0.0002, penalty=none ......................................
# [CV]  alpha=0.0002, penalty=none, score=-0.6597777867822803, total=   1.9s
# [CV] alpha=0.0002, penalty=none ......................................
# [CV]  alpha=0.0002, penalty=none, score=-0.5866548677506939, total=   2.1s
# [CV] alpha=0.0002, penalty=none ......................................
# [CV]  alpha=0.0002, penalty=none, score=-0.8116720767814963, total=   1.9s
# [CV] alpha=0.0002, penalty=none ......................................
# [CV]  alpha=0.0002, penalty=none, score=-0.8500709602066103, total=   1.8s
# [CV] alpha=0.0002, penalty=l2 ........................................
# [CV]  alpha=0.0002, penalty=l2, score=-0.6533728783752264, total=   2.0s
# [CV] alpha=0.0002, penalty=l2 ........................................
# [CV]  alpha=0.0002, penalty=l2, score=-0.5932202407910395, total=   2.0s
# [CV] alpha=0.0002, penalty=l2 ........................................
# [CV]  alpha=0.0002, penalty=l2, score=-0.5384483415567787, total=   2.1s
# [CV] alpha=0.0002, penalty=l2 ........................................
# [CV]  alpha=0.0002, penalty=l2, score=-0.7392909675185253, total=   2.1s
# [CV] alpha=0.0002, penalty=l2 ........................................
# [CV]  alpha=0.0002, penalty=l2, score=-0.7752772940627579, total=   1.9s
# [CV] alpha=0.0002, penalty=l1 ........................................
# [CV]  alpha=0.0002, penalty=l1, score=-0.606011629688349, total=   3.3s
# [CV] alpha=0.0002, penalty=l1 ........................................
# [CV]  alpha=0.0002, penalty=l1, score=-0.5547598898720094, total=   3.2s
# [CV] alpha=0.0002, penalty=l1 ........................................
# [CV]  alpha=0.0002, penalty=l1, score=-0.5009709774765365, total=   3.5s
# [CV] alpha=0.0002, penalty=l1 ........................................
# [CV]  alpha=0.0002, penalty=l1, score=-0.7071262463118723, total=   3.3s
# [CV] alpha=0.0002, penalty=l1 ........................................
# [CV]  alpha=0.0002, penalty=l1, score=-0.7386252190048881, total=   3.0s
# [CV] alpha=0.0005, penalty=none ......................................
# [CV]  alpha=0.0005, penalty=none, score=-0.7243991267042661, total=   1.8s
# [CV] alpha=0.0005, penalty=none ......................................
# [CV]  alpha=0.0005, penalty=none, score=-0.6597777867822803, total=   1.7s
# [CV] alpha=0.0005, penalty=none ......................................
# [CV]  alpha=0.0005, penalty=none, score=-0.5866548677506939, total=   1.9s
# [CV] alpha=0.0005, penalty=none ......................................
# [CV]  alpha=0.0005, penalty=none, score=-0.8116720767814963, total=   1.8s
# [CV] alpha=0.0005, penalty=none ......................................
# [CV]  alpha=0.0005, penalty=none, score=-0.8500709602066103, total=   1.8s
# [CV] alpha=0.0005, penalty=l2 ........................................
# [CV]  alpha=0.0005, penalty=l2, score=-0.591987786348487, total=   1.9s
# [CV] alpha=0.0005, penalty=l2 ........................................
# [CV]  alpha=0.0005, penalty=l2, score=-0.5331918780407661, total=   1.8s
# [CV] alpha=0.0005, penalty=l2 ........................................
# [CV]  alpha=0.0005, penalty=l2, score=-0.49878422071574763, total=   1.9s
# [CV] alpha=0.0005, penalty=l2 ........................................
# [CV]  alpha=0.0005, penalty=l2, score=-0.6729228865630752, total=   1.8s
# [CV] alpha=0.0005, penalty=l2 ........................................
# [CV]  alpha=0.0005, penalty=l2, score=-0.7037960000663266, total=   2.0s
# [CV] alpha=0.0005, penalty=l1 ........................................
# [CV]  alpha=0.0005, penalty=l1, score=-0.5642639009940974, total=   2.6s
# [CV] alpha=0.0005, penalty=l1 ........................................
# [CV]  alpha=0.0005, penalty=l1, score=-0.49848068421388264, total=   2.6s
# [CV] alpha=0.0005, penalty=l1 ........................................
# [CV]  alpha=0.0005, penalty=l1, score=-0.4840839231220867, total=   2.5s
# [CV] alpha=0.0005, penalty=l1 ........................................
# [CV]  alpha=0.0005, penalty=l1, score=-0.6303589494756967, total=   3.0s
# [CV] alpha=0.0005, penalty=l1 ........................................
# [CV]  alpha=0.0005, penalty=l1, score=-0.6830877199739468, total=   2.4s
# [CV] alpha=0.001, penalty=none .......................................
# [CV]  alpha=0.001, penalty=none, score=-0.7243991267042661, total=   1.9s
# [CV] alpha=0.001, penalty=none .......................................
# [CV]  alpha=0.001, penalty=none, score=-0.6597777867822803, total=   1.9s
# [CV] alpha=0.001, penalty=none .......................................
# [CV]  alpha=0.001, penalty=none, score=-0.5866548677506939, total=   1.9s
# [CV] alpha=0.001, penalty=none .......................................
# [CV]  alpha=0.001, penalty=none, score=-0.8116720767814963, total=   1.9s
# [CV] alpha=0.001, penalty=none .......................................
# [CV]  alpha=0.001, penalty=none, score=-0.8500709602066103, total=   1.8s
# [CV] alpha=0.001, penalty=l2 .........................................
# [CV]  alpha=0.001, penalty=l2, score=-0.5494463644913906, total=   1.7s
# [CV] alpha=0.001, penalty=l2 .........................................
# [CV]  alpha=0.001, penalty=l2, score=-0.4925021388662874, total=   1.5s
# [CV] alpha=0.001, penalty=l2 .........................................
# [CV]  alpha=0.001, penalty=l2, score=-0.47588646715071464, total=   1.6s
# [CV] alpha=0.001, penalty=l2 .........................................
# [CV]  alpha=0.001, penalty=l2, score=-0.6197098826228664, total=   1.8s
# [CV] alpha=0.001, penalty=l2 .........................................
# [CV]  alpha=0.001, penalty=l2, score=-0.6452018359504317, total=   1.9s
# [CV] alpha=0.001, penalty=l1 .........................................
# [CV]  alpha=0.001, penalty=l1, score=-0.5671587368573183, total=   2.0s
# [CV] alpha=0.001, penalty=l1 .........................................
# [CV]  alpha=0.001, penalty=l1, score=-0.48270689111663884, total=   1.7s
# [CV] alpha=0.001, penalty=l1 .........................................
# [CV]  alpha=0.001, penalty=l1, score=-0.4891834276480286, total=   1.8s
# [CV] alpha=0.001, penalty=l1 .........................................
# [CV]  alpha=0.001, penalty=l1, score=-0.6196358799110498, total=   1.6s
# [CV] alpha=0.001, penalty=l1 .........................................
# [CV]  alpha=0.001, penalty=l1, score=-0.6505940910531204, total=   1.7s
# [CV] alpha=0.002, penalty=none .......................................
# [CV]  alpha=0.002, penalty=none, score=-0.7243991267042661, total=   1.9s
# [CV] alpha=0.002, penalty=none .......................................
# [CV]  alpha=0.002, penalty=none, score=-0.6597777867822803, total=   1.8s
# [CV] alpha=0.002, penalty=none .......................................
# [CV]  alpha=0.002, penalty=none, score=-0.5866548677506939, total=   2.0s
# [CV] alpha=0.002, penalty=none .......................................
# [CV]  alpha=0.002, penalty=none, score=-0.8116720767814963, total=   2.0s
# [CV] alpha=0.002, penalty=none .......................................
# [CV]  alpha=0.002, penalty=none, score=-0.8500709602066103, total=   1.9s
# [CV] alpha=0.002, penalty=l2 .........................................
# [CV]  alpha=0.002, penalty=l2, score=-0.5331180019098414, total=   1.2s
# [CV] alpha=0.002, penalty=l2 .........................................
# [CV]  alpha=0.002, penalty=l2, score=-0.47191875953719986, total=   1.3s
# [CV] alpha=0.002, penalty=l2 .........................................
# [CV]  alpha=0.002, penalty=l2, score=-0.4763598514241822, total=   1.2s
# [CV] alpha=0.002, penalty=l2 .........................................
# [CV]  alpha=0.002, penalty=l2, score=-0.5925726837007813, total=   1.2s
# [CV] alpha=0.002, penalty=l2 .........................................
# [CV]  alpha=0.002, penalty=l2, score=-0.6105874766860904, total=   1.3s
# [CV] alpha=0.002, penalty=l1 .........................................
# [CV]  alpha=0.002, penalty=l1, score=-0.5963787897086916, total=   0.9s
# [CV] alpha=0.002, penalty=l1 .........................................
# [CV]  alpha=0.002, penalty=l1, score=-0.5129364539291751, total=   1.0s
# [CV] alpha=0.002, penalty=l1 .........................................
# [CV]  alpha=0.002, penalty=l1, score=-0.5162205990911909, total=   1.1s
# [CV] alpha=0.002, penalty=l1 .........................................
# [CV]  alpha=0.002, penalty=l1, score=-0.6369058440687377, total=   1.0s
# [CV] alpha=0.002, penalty=l1 .........................................
# [CV]  alpha=0.002, penalty=l1, score=-0.6209221144281049, total=   1.0s
# [CV] alpha=0.005, penalty=none .......................................
# [CV]  alpha=0.005, penalty=none, score=-0.7243991267042661, total=   1.9s
# [CV] alpha=0.005, penalty=none .......................................
# [CV]  alpha=0.005, penalty=none, score=-0.6597777867822803, total=   1.8s
# [CV] alpha=0.005, penalty=none .......................................
# [CV]  alpha=0.005, penalty=none, score=-0.5866548677506939, total=   1.8s
# [CV] alpha=0.005, penalty=none .......................................
# [CV]  alpha=0.005, penalty=none, score=-0.8116720767814963, total=   1.9s
# [CV] alpha=0.005, penalty=none .......................................
# [CV]  alpha=0.005, penalty=none, score=-0.8500709602066103, total=   1.8s
# [CV] alpha=0.005, penalty=l2 .........................................
# [CV]  alpha=0.005, penalty=l2, score=-0.5464957638678996, total=   0.8s
# [CV] alpha=0.005, penalty=l2 .........................................
# [CV]  alpha=0.005, penalty=l2, score=-0.48107052593005994, total=   0.8s
# [CV] alpha=0.005, penalty=l2 .........................................
# [CV]  alpha=0.005, penalty=l2, score=-0.500466501662022, total=   0.8s
# [CV] alpha=0.005, penalty=l2 .........................................
# [CV]  alpha=0.005, penalty=l2, score=-0.584626201544181, total=   0.8s
# [CV] alpha=0.005, penalty=l2 .........................................
# [CV]  alpha=0.005, penalty=l2, score=-0.6032384324170719, total=   0.8s
# [CV] alpha=0.005, penalty=l1 .........................................
# [CV]  alpha=0.005, penalty=l1, score=-0.6105697696779018, total=   0.7s
# [CV] alpha=0.005, penalty=l1 .........................................
# [CV]  alpha=0.005, penalty=l1, score=-0.5322526672791296, total=   0.8s
# [CV] alpha=0.005, penalty=l1 .........................................
# [CV]  alpha=0.005, penalty=l1, score=-0.562455281590321, total=   0.9s
# [CV] alpha=0.005, penalty=l1 .........................................
# [CV]  alpha=0.005, penalty=l1, score=-0.6229793810772476, total=   0.8s
# [CV] alpha=0.005, penalty=l1 .........................................
# [CV]  alpha=0.005, penalty=l1, score=-0.6003802195179274, total=   0.9s
# [CV] alpha=0.01, penalty=none ........................................
# [CV]  alpha=0.01, penalty=none, score=-0.7243991267042661, total=   2.0s
# [CV] alpha=0.01, penalty=none ........................................
# [CV]  alpha=0.01, penalty=none, score=-0.6597777867822803, total=   2.0s
# [CV] alpha=0.01, penalty=none ........................................
# [CV]  alpha=0.01, penalty=none, score=-0.5866548677506939, total=   2.1s
# [CV] alpha=0.01, penalty=none ........................................
# [CV]  alpha=0.01, penalty=none, score=-0.8116720767814963, total=   2.1s
# [CV] alpha=0.01, penalty=none ........................................
# [CV]  alpha=0.01, penalty=none, score=-0.8500709602066103, total=   1.8s
# [CV] alpha=0.01, penalty=l2 ..........................................
# [CV] .. alpha=0.01, penalty=l2, score=-0.56539438504463, total=   0.6s
# [CV] alpha=0.01, penalty=l2 ..........................................
# [CV]  alpha=0.01, penalty=l2, score=-0.5002314037120589, total=   0.6s
# [CV] alpha=0.01, penalty=l2 ..........................................
# [CV]  alpha=0.01, penalty=l2, score=-0.5302771915615305, total=   0.6s
# [CV] alpha=0.01, penalty=l2 ..........................................
# [CV]  alpha=0.01, penalty=l2, score=-0.5870106906700073, total=   0.6s
# [CV] alpha=0.01, penalty=l2 ..........................................
# [CV] . alpha=0.01, penalty=l2, score=-0.607859139586523, total=   0.6s
# [CV] alpha=0.01, penalty=l1 ..........................................
# [CV]  alpha=0.01, penalty=l1, score=-0.6301562731405299, total=   0.5s
# [CV] alpha=0.01, penalty=l1 ..........................................
# [CV]  alpha=0.01, penalty=l1, score=-0.5495879955058595, total=   0.6s
# [CV] alpha=0.01, penalty=l1 ..........................................
# [CV]  alpha=0.01, penalty=l1, score=-0.5891939413262621, total=   0.7s
# [CV] alpha=0.01, penalty=l1 ..........................................
# [CV]  alpha=0.01, penalty=l1, score=-0.6292951895374105, total=   0.5s
# [CV] alpha=0.01, penalty=l1 ..........................................
# [CV]  alpha=0.01, penalty=l1, score=-0.6385907594535283, total=   0.7s
# [CV] alpha=0.02, penalty=none ........................................
# [CV]  alpha=0.02, penalty=none, score=-0.7243991267042661, total=   1.9s
# [CV] alpha=0.02, penalty=none ........................................
# [CV]  alpha=0.02, penalty=none, score=-0.6597777867822803, total=   1.9s
# [CV] alpha=0.02, penalty=none ........................................
# [CV]  alpha=0.02, penalty=none, score=-0.5866548677506939, total=   1.8s
# [CV] alpha=0.02, penalty=none ........................................
# [CV]  alpha=0.02, penalty=none, score=-0.8116720767814963, total=   1.8s
# [CV] alpha=0.02, penalty=none ........................................
# [CV]  alpha=0.02, penalty=none, score=-0.8500709602066103, total=   1.9s
# [CV] alpha=0.02, penalty=l2 ..........................................
# [CV]  alpha=0.02, penalty=l2, score=-0.5878642600900479, total=   0.5s
# [CV] alpha=0.02, penalty=l2 ..........................................
# [CV]  alpha=0.02, penalty=l2, score=-0.5177584832192352, total=   0.4s
# [CV] alpha=0.02, penalty=l2 ..........................................
# [CV]  alpha=0.02, penalty=l2, score=-0.5580066187460483, total=   0.5s
# [CV] alpha=0.02, penalty=l2 ..........................................
# [CV]  alpha=0.02, penalty=l2, score=-0.5997409549994038, total=   0.4s
# [CV] alpha=0.02, penalty=l2 ..........................................
# [CV]  alpha=0.02, penalty=l2, score=-0.6170829824818108, total=   0.6s
# [CV] alpha=0.02, penalty=l1 ..........................................
# [CV]  alpha=0.02, penalty=l1, score=-0.6222308995166637, total=   0.4s
# [CV] alpha=0.02, penalty=l1 ..........................................
# [CV]  alpha=0.02, penalty=l1, score=-0.5564176984375131, total=   0.5s
# [CV] alpha=0.02, penalty=l1 ..........................................
# [CV]  alpha=0.02, penalty=l1, score=-0.5971502344049845, total=   0.6s
# [CV] alpha=0.02, penalty=l1 ..........................................
# [CV]  alpha=0.02, penalty=l1, score=-0.6092398610572116, total=   0.7s
# [CV] alpha=0.02, penalty=l1 ..........................................
# [CV]  alpha=0.02, penalty=l1, score=-0.6514737094365116, total=   0.5s
# [CV] alpha=0.05, penalty=none ........................................
# [CV]  alpha=0.05, penalty=none, score=-0.7243991267042661, total=   2.0s
# [CV] alpha=0.05, penalty=none ........................................
# [CV]  alpha=0.05, penalty=none, score=-0.6597777867822803, total=   1.9s
# [CV] alpha=0.05, penalty=none ........................................
# [CV]  alpha=0.05, penalty=none, score=-0.5866548677506939, total=   1.9s
# [CV] alpha=0.05, penalty=none ........................................
# [CV]  alpha=0.05, penalty=none, score=-0.8116720767814963, total=   1.9s
# [CV] alpha=0.05, penalty=none ........................................
# [CV]  alpha=0.05, penalty=none, score=-0.8500709602066103, total=   2.0s
# [CV] alpha=0.05, penalty=l2 ..........................................
# [CV]  alpha=0.05, penalty=l2, score=-0.6096889566237388, total=   0.3s
# [CV] alpha=0.05, penalty=l2 ..........................................
# [CV]  alpha=0.05, penalty=l2, score=-0.5344828590267476, total=   0.4s
# [CV] alpha=0.05, penalty=l2 ..........................................
# [CV]  alpha=0.05, penalty=l2, score=-0.5804169101937485, total=   0.4s
# [CV] alpha=0.05, penalty=l2 ..........................................
# [CV]  alpha=0.05, penalty=l2, score=-0.6084137850056797, total=   0.4s
# [CV] alpha=0.05, penalty=l2 ..........................................
# [CV]  alpha=0.05, penalty=l2, score=-0.6306304879781289, total=   0.3s
# [CV] alpha=0.05, penalty=l1 ..........................................
# [CV]  alpha=0.05, penalty=l1, score=-0.6313419626348795, total=   0.5s
# [CV] alpha=0.05, penalty=l1 ..........................................
# [CV]  alpha=0.05, penalty=l1, score=-0.5488494062676604, total=   0.6s
# [CV] alpha=0.05, penalty=l1 ..........................................
# [CV] . alpha=0.05, penalty=l1, score=-0.597080613823551, total=   0.5s
# [CV] alpha=0.05, penalty=l1 ..........................................
# [CV]  alpha=0.05, penalty=l1, score=-0.6090662577021522, total=   0.5s
# [CV] alpha=0.05, penalty=l1 ..........................................
# [CV]  alpha=0.05, penalty=l1, score=-0.6408446528953323, total=   0.6s
# [CV] alpha=0.1, penalty=none .........................................
# [CV]  alpha=0.1, penalty=none, score=-0.7243991267042661, total=   2.1s
# [CV] alpha=0.1, penalty=none .........................................
# [CV]  alpha=0.1, penalty=none, score=-0.6597777867822803, total=   2.2s
# [CV] alpha=0.1, penalty=none .........................................
# [CV]  alpha=0.1, penalty=none, score=-0.5866548677506939, total=   2.0s
# [CV] alpha=0.1, penalty=none .........................................
# [CV]  alpha=0.1, penalty=none, score=-0.8116720767814963, total=   2.0s
# [CV] alpha=0.1, penalty=none .........................................
# [CV]  alpha=0.1, penalty=none, score=-0.8500709602066103, total=   1.8s
# [CV] alpha=0.1, penalty=l2 ...........................................
# [CV] . alpha=0.1, penalty=l2, score=-0.6171711533743612, total=   0.3s
# [CV] alpha=0.1, penalty=l2 ...........................................
# [CV] . alpha=0.1, penalty=l2, score=-0.5416253351567498, total=   0.3s
# [CV] alpha=0.1, penalty=l2 ...........................................
# [CV] .. alpha=0.1, penalty=l2, score=-0.588511432758965, total=   0.4s
# [CV] alpha=0.1, penalty=l2 ...........................................
# [CV] .. alpha=0.1, penalty=l2, score=-0.608703171189364, total=   0.3s
# [CV] alpha=0.1, penalty=l2 ...........................................
# [CV] . alpha=0.1, penalty=l2, score=-0.6356729937953047, total=   0.3s
# [CV] alpha=0.1, penalty=l1 ...........................................
# [CV] . alpha=0.1, penalty=l1, score=-0.6313576080023211, total=   0.5s
# [CV] alpha=0.1, penalty=l1 ...........................................
# [CV] . alpha=0.1, penalty=l1, score=-0.5488461691264115, total=   0.5s
# [CV] alpha=0.1, penalty=l1 ...........................................
# [CV] . alpha=0.1, penalty=l1, score=-0.5970773882648134, total=   0.5s
# [CV] alpha=0.1, penalty=l1 ...........................................
# [CV] . alpha=0.1, penalty=l1, score=-0.6090384048502827, total=   0.5s
# [CV] alpha=0.1, penalty=l1 ...........................................
# [CV] . alpha=0.1, penalty=l1, score=-0.6408427046813518, total=   0.5s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:  3.8min finished
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/model_selection/_search.py:842: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Time to train model: 228.71s

# %%
with joblib.parallel_backend('dask'):
    model = gs.best_estimator_
print(gs.best_params_)
print(gs.best_score_)
# Out:
# {'alpha': 0.002, 'penalty': 'l2'}
# -0.5368059524741735

# %%
with joblib.parallel_backend('dask'):
    pipe = Pipeline([('vect',vect),('model',model)])
    start = time.time()
    y_pred = pipe.predict(X_test)
end = time.time()
print('Time to generate predictions on test set: %0.2fs' % (end - start))
# Out:
# Time to generate predictions on test set: 0.01s

# %%
with joblib.parallel_backend('dask'):
    print(np.sqrt(mean_squared_log_error(np.exp(y_test)-1, np.exp(y_pred)-1)))
# Out:
# 0.7132962188193676

# %%
df_test = dd.read_csv('test.tsv', sep='\t')
df_test=df_test.compute()

# %%
df_test['item_description'].fillna('Missing', inplace=True)
df_test['price'] = np.exp(pipe.predict((df_test['name'] + ' ' + df_test['item_description']).values))-1
df_test
# Out:
#      test_id                                      name  item_condition_id  \
# 0          0  Breast cancer "I fight like a girl" ring                  1
# 1          1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers                  1
# 2          2                                 Coach bag                  1
# 3          3                             Floral Kimono                  2
# 4          4                          Life after Death                  3
# ..       ...                                       ...                ...
# 994      994             American Apparel Riding Pants                  1
# 995      995             VS Water Bottle And Lip Stick                  1
# 996      996                             Express Jeans                  2
# 997      997                Victoria Secret Duffle Bag                  2
# 998      998             Dipper Pines CHASE Funko POP!                  1
#
#                                       category_name        brand_name  \
# 0                               Women/Jewelry/Rings               NaN
# 1           Other/Office supplies/Shipping Supplies               NaN
# 2    Vintage & Collectibles/Bags and Purses/Handbag             Coach
# 3                           Women/Sweaters/Cardigan               NaN
# 4               Other/Books/Religion & Spirituality               NaN
# ..                                              ...               ...
# 994  Women/Athletic Apparel/Pants, Tights, Leggings  American Apparel
# 995                               Women/Other/Other              PINK
# 996                        Women/Jeans/Slim, Skinny           Express
# 997         Women/Women's Handbags/Totes & Shoppers              PINK
# 998              Kids/Toys/Action Figures & Statues             Funko
#
#      shipping                                   item_description      price
# 0           1                                             Size 7  16.986330
# 1           1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers Lined...  12.767607
# 2           1  Brand new coach bag. Bought for [rm] at a Coac...  18.752340
# 3           0  -floral kimono -never worn -lightweight and pe...  14.054427
# 4           1  Rediscovering life after the loss of a loved o...  14.676350
# ..        ...                                                ...        ...
# 994         1  Extremely high waisted riding pants. The color...  11.391368
# 995         1  Clear water bottle with black lettering "kiss ...  17.050184
# 996         0  Size 8. Skinny ankle (Stella low rise). Dark w...  11.607735
# 997         0                       Used one time still has tags  13.721761
# 998         1                       What you see is what you get  16.257391
#
# [999 rows x 8 columns]
